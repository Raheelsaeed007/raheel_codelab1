# %% [markdown]
# <a href="https://colab.research.google.com/github/Raheelsaeed007/raheel_codelab1/blob/main/chapter%206-loops/chapter_6_excercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#infinity
#write a loop that never ends

count=333
while count<=333:
  print(count)
# Out:
# Streaming output truncated to the last 5000 lines.
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# 333
# ...
