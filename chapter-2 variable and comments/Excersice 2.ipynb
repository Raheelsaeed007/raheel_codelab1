# %%
msg = ("combination")
print('Nelson mandela once said, " “A good head and a good heart are always a formidable combination."')
# Out:
# Nelson mandela once said, " “A good head and a good heart are always a formidable combination."
