# %%
#Assigning a name to a variable
Name = "      Raheel Saeed      "

#using combinations “\t” and “\n”
Name2 = ("\n RaheelSaeed")
Name3 = ("\t Raheel Saeed")
print("When we use \ n:"+Name2 +"\n"+"When we use \ t:"+Name3)

#using three stripping functions, lstrip(), rstrip(), and strip()

print("\n using no fucntion:")
print(Name)

print("\n using lstrip():")
print(Name.lstrip())

print("\n using rstrip():")
print(Name.rstrip())

print("\n using strip():")
print(Name.strip())
# Out:
# When we use \ n:
#  RaheelSaeed
# When we use \ t:	 Raheel Saeed
#
#  using no fucntion:
#       Raheel Saeed
#
#  using lstrip():
# Raheel Saeed
#
#  using rstrip():
#       Raheel Saeed
#
#  using strip():
# Raheel Saeed
