# %%
print("Hello everyone")
print("My name is Muhammad Rahil")
print("Im doing my first year of university")
print("The name of university is bath spa")
# Out:
# Hello everyone
# My name is Muhammad Rahil
# Im doing my first year of university
# The name of university is bath spa

# %%
# Asking user for double values
print("enter two number for calculation")
# Assigning the number to variables
a=int(input())
b=int(input())

#calculation
print('The Power of '+str(a)+' and '+str(b)+' is',str(a**b))
# Out:
# enter two number for calculation
# 5
# 6
# The Power of 5 and 6 is 15625

# %%
# Asking user for double values
print("enter two number for calculation")
# Assigning the number to variables
a=int(input())
b=int(input())

#calculation
print('The Modulus of '+str(a)+' and '+str(b)+' is',str(a%b))
# Out:
# enter two number for calculation
# 8
# 9
# The Modulus of 8 and 9 is 8

# %%
# Asking user for double values
print("enter two number for calculation")
# Assigning the number to variables
a=int(input())
b=int(input())

#calculation
print('The division of '+str(a)+' and '+str(b)+' is',str(a/b))
# Out:
# enter two number for calculation
# 5
# 8
# The division of 5 and 8 is 0.625

# %%
# Asking user for double values5
print("enter two number for calculation")
# Assigning the number to variables
a=int(input())
b=int(input())

#calculation
print('The Multiplication of '+str(a)+' and '+str(b)+' is',str(a*b))
# Out:
# enter two number for calculation
# 5
# 6
# The Multiplication of 5 and 6 is 30
