# %%
#my favourite mode of transport
transport_modes=["car","bike","metro"]
print("i love to drive ,"+transport_modes [0].title()+".")
print("i also like to travel in ,"+transport_modes [1].title()+".")
print("sometimes when roads are busy i like to travel on,"+transport_modes [2].title()+".")
# Out:
# i love to drive ,Car.
# i also like to travel in ,Bike.
# sometimes when roads are busy i like to travel on,Metro.
