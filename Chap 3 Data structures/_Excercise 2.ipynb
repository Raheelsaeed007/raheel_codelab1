# %%
#print a message to your friend
names=["Awais","Asif","ibrar"]
print("hello nice to meet you,"+names[0].title()+".")
print("how are you,"+names[1].title()+".")
print("where are you,"+names[2].title()+".")
# Out:
# hello nice to meet you,Awais.
# how are you,Asif.
# where are you,Ibrar.
