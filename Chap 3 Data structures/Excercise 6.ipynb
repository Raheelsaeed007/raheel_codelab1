# %%
#shrinking guest list because new dinner table won't arrive in time for dinner
guest_list=["awais","fawaz","imran"]
print("I am sorry to inform you that i can only invite two people for tonight dinner table have only space for two guests")

print("sorry my dear friend you are not invited for tonight's dinner,"+guest_list[2].title()+".")
guest_list.pop(2)
print(guest_list)

del guest_list[:]
# Out:
# I am sorry to inform you that i can only invite two people for tonight dinner table have only space for two guests
# sorry my dear friend you are not invited for tonight's dinner,Imran.
# ['awais', 'fawaz']
