# %%
from math import pi
r= float(input("input the radius of the circle:"))
print("the area of the circle wuth radius " +str (r)+" is:"+str(pi*r**2))
# Out:
# input the radius of the circle:5
# the area of the circle wuth radius 5.0 is:78.53981633974483
